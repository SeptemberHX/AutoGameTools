# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

person_1= cv2.imread('test_home.png')
grayScale_1 = cv2.cvtColor(person_1, cv2.IMREAD_GRAYSCALE)
person_2 = cv2.imread('home_mark.png')
grayScale_2 = cv2.cvtColor(person_2, cv2.IMREAD_GRAYSCALE)

plt.figure()
plt.imshow(person_1)

plt.figure()
plt.imshow(person_2)
